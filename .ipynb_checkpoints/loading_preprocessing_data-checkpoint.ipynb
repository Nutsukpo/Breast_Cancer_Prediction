# %% [markdown]
# ## Project Description : Car Price Prediciton

# %% [markdown]
# ## Import Libraries

# %%
## for loading and preprocessing 
import pandas as pd
import numpy as np 

## for data visualization 
import matplotlib.pyplot as plt
import seaborn as sns

## splitting dataset
from sklearn.model_selection import train_test_split

## feature engineering
from sklearn.feature_extraction import DictVectorizer

## load regression model 
from sklearn.linear_model import LinearRegression

## evaluation metric
from sklearn.metrics import mean_absolute_error, mean_squared_error, root_mean_squared_error

# %% [markdown]
# ## Loading Data & Creating Copy

# %%
## read dataset
data = pd.read_csv("dataset/car_price_prediction.csv")

# %%
## create a deep copy 
df = data.copy()

# %% [markdown]
# ## Data Preview And Understanding
# - Loading the dataset

# %%
## view the first rows 
df.head()
# Out:
#          ID  Price  Levy Manufacturer    Model  Prod. year   Category  \
# 0  45654403  13328  1399        LEXUS   RX 450        2010       Jeep
# 1  44731507  16621  1018    CHEVROLET  Equinox        2011       Jeep
# 2  45774419   8467     -        HONDA      FIT        2006  Hatchback
# 3  45769185   3607   862         FORD   Escape        2011       Jeep
# 4  45809263  11726   446        HONDA      FIT        2014  Hatchback
#
#   Leather interior Fuel type Engine volume    Mileage  Cylinders  \
# 0              Yes    Hybrid           3.5  186005 km        6.0
# 1               No    Petrol             3  192000 km        6.0
# 2               No    Petrol           1.3  200000 km        4.0
# 3              Yes    Hybrid           2.5  168966 km        4.0
# 4              Yes    Petrol           1.3   91901 km        4.0
#
#   Gear box type Drive wheels   Doors             Wheel   Color  Airbags
# 0     Automatic          4x4  04-May        Left wheel  Silver       12
# 1     Tiptronic          4x4  04-May        Left wheel   Black        8
# 2      Variator        Front  04-May  Right-hand drive   Black        2
# 3     Automatic          4x4  04-May        Left wheel   White        0
# 4     Automatic        Front  04-May        Left wheel  Silver        4

# %%
## view the last five rows 
df.tail()
# Out:
#              ID  Price  Levy   Manufacturer    Model  Prod. year Category  \
# 19232  45798355   8467     -  MERCEDES-BENZ  CLK 200        1999    Coupe
# 19233  45778856  15681   831        HYUNDAI   Sonata        2011    Sedan
# 19234  45804997  26108   836        HYUNDAI   Tucson        2010     Jeep
# 19235  45793526   5331  1288      CHEVROLET  Captiva        2007     Jeep
# 19236  45813273    470   753        HYUNDAI   Sonata        2012    Sedan
#
#       Leather interior Fuel type Engine volume    Mileage  Cylinders  \
# 19232              Yes       CNG     2.0 Turbo  300000 km        4.0
# 19233              Yes    Petrol           2.4  161600 km        4.0
# 19234              Yes    Diesel             2  116365 km        4.0
# 19235              Yes    Diesel             2   51258 km        4.0
# 19236              Yes    Hybrid           2.4  186923 km        4.0
#
#       Gear box type Drive wheels   Doors       Wheel   Color  Airbags
# 19232        Manual         Rear  02-Mar  Left wheel  Silver        5
# 19233     Tiptronic        Front  04-May  Left wheel     Red        8
# 19234     Automatic        Front  04-May  Left wheel    Grey        4
# 19235     Automatic        Front  04-May  Left wheel   Black        4
# 19236     Automatic        Front  04-May  Left wheel   White       12

# %%
## check the number of rows and columns 
print(f'Total number of rows: {df.shape[0]} -> Total number of columns: {df.shape[1]}')
# Out:
# Total number of rows: 19237 -> Total number of columns: 18

# %%
## get a summary description of the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19237 entries, 0 to 19236
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                19237 non-null  int64
#  1   Price             19237 non-null  int64
#  2   Levy              19237 non-null  object
#  3   Manufacturer      19237 non-null  object
#  4   Model             19237 non-null  object
#  5   Prod. year        19237 non-null  int64
#  6   Category          19237 non-null  object
#  7   Leather interior  19237 non-null  object
#  8   Fuel type         19237 non-null  object
#  9   Engine volume     19237 non-null  object
#  10  Mileage           19237 non-null  object
#  11  Cylinders         19237 non-null  float64
#  12  Gear box type     19237 non-null  object
#  13  Drive wheels      19237 non-null  object
#  14  Doors             19237 non-null  object
#  15  Wheel             19237 non-null  object
#  16  Color             19237 non-null  object
#  17  Airbags           19237 non-null  int64
# dtypes: float64(1), int64(4), object(13)
# memory usage: 2.6+ MB

# %%
## checking for missing values
df.isnull().sum()
# Out:
# ID                  0
# Price               0
# Levy                0
# Manufacturer        0
# Model               0
# Prod. year          0
# Category            0
# Leather interior    0
# Fuel type           0
# Engine volume       0
# Mileage             0
# Cylinders           0
# Gear box type       0
# Drive wheels        0
# Doors               0
# Wheel               0
# Color               0
# Airbags             0
# dtype: int64

# %%
## checking for duplicated values 
df.duplicated().sum()
# Out:
# 313

# %%
## checking type on columns
df.dtypes
# Out:
# ID                    int64
# Price                 int64
# Levy                 object
# Manufacturer         object
# Model                object
# Prod. year            int64
# Category             object
# Leather interior     object
# Fuel type            object
# Engine volume        object
# Mileage              object
# Cylinders           float64
# Gear box type        object
# Drive wheels         object
# Doors                object
# Wheel                object
# Color                object
# Airbags               int64
# dtype: object

# %%
## finding unique instances in each column 
print(np.unique(df['Price']))
# Out:
# [       1        3        6 ...   627220   872946 26307500]

# %%
## finding unique instances in each column 
print(np.unique(df['Model']))
# Out:
# ['09-Mar' '100' '100 NX' ... 'macan S' 'tC' 'xD']

# %%
print(np.unique(df['Mileage']))
# Out:
# ['0 km' '1000 km' '10000 km' ... '99999 km' '999999 km' '999999999 km']

# %% [markdown]
# ## Data preprocessing
# - replacing unsual characters with NaN values
# - Drop the Id column
# - Normalizing column names
# - Remove km from Mileage column
# - Filling of missing

# %%
df['Levy'] = df['Levy'].replace('-', np.nan)

# %%
## finding unique instances in each column 
##print(np.unique(df['Levy']))

# %%
df = df.drop(['ID'], axis=1)

# %%
##change column names to lower case and replace spaces with underscore
df.columns = df.columns.str.lower().str.replace(' ', '_')

# %%
df.columns
# Out:
# Index(['price', 'levy', 'manufacturer', 'model', 'prod._year', 'category',
#        'leather_interior', 'fuel_type', 'engine_volume', 'mileage',
#        'cylinders', 'gear_box_type', 'drive_wheels', 'doors', 'wheel', 'color',
#        'airbags'],
#       dtype='object')

# %%
## remove km from the mileage column
df['mileage'] = df['mileage'].str.replace(' km', '')
df['mileage'] = df['mileage'].str.replace('-km', '')

# %%
## convert the mileage column type to float
df['mileage'] = df['mileage'].astype('int64')

# %%
df['levy'].isnull().sum()
# Out:
# 5819

# %%
## converting column type to float
df['levy'] = df['levy'].astype('float')

# %%
df['levy'] = df['levy'].fillna(df['levy'].mean())

# %%
df['levy'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ## Exploratory Data Analysis
# - statistical summary
# - Target variable analysis
# - Plot a coorelation against the target variable

# %%
df.describe().round()
# Out:
#             price     levy  prod._year       mileage  cylinders  airbags
# count     19237.0  19237.0     19237.0  1.923700e+04    19237.0  19237.0
# mean      18556.0    907.0      2011.0  1.532236e+06        5.0      7.0
# std      190581.0    386.0         6.0  4.840387e+07        1.0      4.0
# min           1.0     87.0      1939.0  0.000000e+00        1.0      0.0
# 25%        5331.0    730.0      2009.0  7.013900e+04        4.0      4.0
# 50%       13172.0    907.0      2012.0  1.260000e+05        4.0      6.0
# 75%       22075.0    917.0      2015.0  1.888880e+05        4.0     12.0
# max    26307500.0  11714.0      2020.0  2.147484e+09       16.0     16.0

# %%
sns.histplot(df['price'][df['price'] < 100000])

plt.title('Histogram Distribution of Price')
plt.xlabel('Price')
plt.ylabel('Frequency')

plt.show()

# %%
## log transformation 
log_price = np.log1p(df['price'])

# %%
sns.histplot(log_price)

plt.title('Histogram Distribution of the Log Price')
plt.xlabel('Price')
plt.ylabel('Frequency')

plt.show()

# %%
## performing a coorelation on numerical column
## select numerical

numerical_cols = df.select_dtypes(exclude=[object])
corr_matrix = numerical_cols.corr()
corr_matrix['price']
# Out:
# price         1.000000
# levy          0.005373
# prod._year    0.012982
# mileage      -0.001758
# cylinders     0.007518
# airbags      -0.012824
# Name: price, dtype: float64

# %%
## correlation for non-numerical


## Manufacturer, Model, Category, Leather interior, Fuel type, Gearbox ype, drive wheels, wheel, color

# %% [markdown]
# ## Building A Validation Framework / Splitting Dataset
# - Training set 60 %
# - Validation dataset 20%
# - Test dataset 20%

# %%
df_train_full, df_test = train_test_split(df, test_size=0.2, random_state=11)

df_train, df_valid = train_test_split(df_train_full, test_size=0.25, random_state=11) 

print(f'Train set {len(df_train)}')
print(f'Valid set {len(df_valid)}')
print(f'Test set {len(df_test)}')
# Out:
# Train set 11541
# Valid set 3848
# Test set 3848

# %%
df_train.head()
# Out:
#        price    levy manufacturer           model  prod._year     category  \
# 18929   8781  1268.0       TOYOTA            Aqua        2012        Sedan
# 7985   25089   585.0       TOYOTA  Prius V HYBRID        2013    Hatchback
# 5374    8320   640.0          KIA          Optima        2013        Sedan
# 2925   16621   562.0    CHEVROLET           Cruze        2015        Sedan
# 16823  14113   769.0         FORD         Transit        2011  Goods wagon
#
#       leather_interior fuel_type engine_volume  mileage  cylinders  \
# 18929               No    Hybrid           1.5    87000        4.0
# 7985                No    Hybrid           1.8    65649        4.0
# 5374               Yes    Petrol             2    52448        4.0
# 2925               Yes    Petrol     1.4 Turbo   144000        4.0
# 16823               No    Diesel     2.2 Turbo   165852        4.0
#
#       gear_box_type drive_wheels   doors             wheel     color  airbags
# 18929     Automatic        Front  04-May  Right-hand drive     Black        2
# 7985       Variator        Front  04-May        Left wheel  Sky blue        9
# 5374      Automatic        Front  04-May        Left wheel    Silver        4
# 2925      Tiptronic        Front  04-May        Left wheel     White       12
# 16823        Manual        Front  04-May        Left wheel     White        2

# %%
## selecting target column and converting it to a vector format
y_train = np. df_train['price'].values
y_valid = df_valid['price'].values
y_test = df_test['price'].values
y_train_full = df_train_full['price'].values

# %%
#y_train

# %%
del df_train['price']
del df_valid['price']
del df_test['price']
del df_train_full['price']

# %% [markdown]
# ## Train A Baseline Regression Model
# - Selecting baseline features
# - Train a regression model

# %%
df_train.columns
# Out:
# Index(['levy', 'manufacturer', 'model', 'prod._year', 'category',
#        'leather_interior', 'fuel_type', 'engine_volume', 'mileage',
#        'cylinders', 'gear_box_type', 'drive_wheels', 'doors', 'wheel', 'color',
#        'airbags'],
#       dtype='object')

# %%
baseline_features = ['levy', 'prod._year', 'cylinders', 'airbags']

df_train_bl = df_train[baseline_features]

# %%
df_train_bl.isnull().sum()
# Out:
# levy          0
# prod._year    0
# cylinders     0
# airbags       0
# dtype: int64

# %%
X_train_bl = df_train_bl.values
X_train_bl
# Out:
# array([[1.268e+03, 2.012e+03, 4.000e+00, 2.000e+00],
#        [5.850e+02, 2.013e+03, 4.000e+00, 9.000e+00],
#        [6.400e+02, 2.013e+03, 4.000e+00, 4.000e+00],
#        ...,
#        [5.620e+02, 2.015e+03, 4.000e+00, 1.000e+01],
#        [9.190e+02, 2.012e+03, 6.000e+00, 1.200e+01],
#        [1.807e+03, 2.012e+03, 8.000e+00, 1.200e+01]])

# %%
df_train.dtypes
# Out:
# levy                float64
# manufacturer         object
# model                object
# prod._year            int64
# category             object
# leather_interior     object
# fuel_type            object
# engine_volume        object
# mileage               int64
# cylinders           float64
# gear_box_type        object
# drive_wheels         object
# doors                object
# wheel                object
# color                object
# airbags               int64
# dtype: object

# %%
## lets train model 
model = LinearRegression() 
model.fit(X_train_bl, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Model Evaluation
# - Generate the validation predictions
# - Compare the validation predictions to the actual predictions
# - Return an accuracy score

# %%
## generate validation baseline features
df_valid_bl = df_valid[baseline_features]

## convert dataframe into numpy array
X_valid_bl = df_valid_bl.values
X_valid_bl
# Out:
# array([[ 906.83812789, 2008.        ,    4.        ,    4.        ],
#        [ 906.83812789, 2012.        ,    8.        ,    8.        ],
#        [ 640.        , 2013.        ,    4.        ,    4.        ],
#        ...,
#        [1537.        , 2009.        ,    6.        ,   12.        ],
#        [ 784.        , 2017.        ,    4.        ,    4.        ],
#        [ 906.83812789, 1999.        ,    6.        ,    6.        ]])

# %%
## generate our validation prediction
y_valid_pred = model.predict(X_valid_bl)

# %%
acc_score = model.score(X_valid_bl, y_valid)
print(f'Baseline Validation Accuracy: {acc_score}')
# Out:
# Baseline Validation Accuracy: 0.00158482645647684

# %%
rsquared_acc = r2_score(y_valid, y_valid_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 rsquared_acc = r2_score(y_valid, y_valid_pred)
#
# NameError: name 'r2_score' is not defined

# %%
print(f'The Mean Accuracy for the Model: {rsquared_acc}')

# %% [markdown]
# ## Feature Engineering
#
# - Convert categorical data to numerical using one-hot encoding

# %%
## select categoricals

categorical_features = ['manufacturer', 'model', 'category', 'leather_interior', 'fuel_type', 'gear_box_type', 'drive_wheels', 'wheel']
numerical_features = ['levy', 'prod._year', 'mileage','cylinders','airbags']

df_train_fe = df_train[categorical_features + numerical_features]

##
train_dict_fe = df_train_fe.to_dict(orient='records')

# %%
## convert our dataframe to a list of dict vectorizer

dv = DictVectorizer()
dv.fit(train_dict_fe)
# Out:
# DictVectorizer()

# %%
##
X_train_fe = dv.transform(train_dict_fe)

# %%
X_train_fe
# Out:
# <11541x1274 sparse matrix of type '<class 'numpy.float64'>'
# 	with 150033 stored elements in Compressed Sparse Row format>

# %%
## dv.get_feature_names_out()
# Out:
# array(['airbags', 'category=Cabriolet', 'category=Coupe', ...,
#        'prod._year', 'wheel=Left wheel', 'wheel=Right-hand drive'],
#       dtype=object)

# %% [markdown]
# ## Train Model
# - df_train_full, df_test

# %%
df_train_final = df_train_full[baseline_features]
X_train_full = df_train_final.values

# %%
df_test_final = df_test[baseline_features]
X_test = df_test_final.values

# %%
final_model = LinearRegression()

final_model.fit(X_train_full, y_train_full)

# %%
y_test_predict = final_model.predict(X_test)

# %%
rmse = root_mean_squared_error(y_test, y_test_predict)
print(f'Final Model Accuracy: {rmse}')
